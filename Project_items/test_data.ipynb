# %%
import pandas as pd

import os
import glob
import datetime

# %%
# Merge top 200
files = glob.glob('Resources/Top200/May/*.csv')
# print(files)

may_combined_df_top200 = pd.concat([pd.read_csv(fp, skiprows=[0], skip_blank_lines=True).assign(Filename=os.path.basename(fp)) for fp in files])

may_combined_df_top200
may_combined_df_top200 = may_combined_df_top200.sort_values(['Filename', "Position"], ascending=True)

# %%
may_combined_df_top200
# Out:
#      Position                                Track Name               Artist  \
# 0           1                                THE SCOTTS           THE SCOTTS
# 1           2                              Toosie Slide                Drake
# 2           3            Pain 1993 (with Playboi Carti)                Drake
# 3           4              ROCKSTAR (feat. Roddy Ricch)               DaBaby
# 4           5              Savage Remix (feat. Beyoncé)  Megan Thee Stallion
# ..        ...                                       ...                  ...
# 195       196                                   Legends           Juice WRLD
# 196       197  Meant to Be (feat. Florida Georgia Line)           Bebe Rexha
# 197       198                                 Hurricane           Luke Combs
# 198       199                            No Role Modelz              J. Cole
# 199       200                                 Lights Up         Harry Styles
#
#       Streams                                                URL  \
# 0    12864147  https://open.spotify.com/track/39Yp9wwQiSRIDOv...
# 1    11648985  https://open.spotify.com/track/466cKvZn1j45Ipx...
# 2    10082722  https://open.spotify.com/track/6Kj17Afjo1OKJYp...
# 3    10028561  https://open.spotify.com/track/7ytR5pFWmSjzHJI...
# 4     8965215  https://open.spotify.com/track/5v4GgrXPMghOnBB...
# ..        ...                                                ...
# 195   1496245  https://open.spotify.com/track/1Knctxx9vGZxpZf...
# 196   1495527  https://open.spotify.com/track/4e4fqjx0Izh4svv...
# 197   1495471  https://open.spotify.com/track/6xHI9KjUjYT0FPt...
# 198   1495066  https://open.spotify.com/track/62vpWI1CHwFy7tM...
# 199   1494534  https://open.spotify.com/track/4jAIqgrPjKLTY9G...
#
#                                           Filename
# 0    regional-us-weekly-2020-05-01--2020-05-08.csv
# 1    regional-us-weekly-2020-05-01--2020-05-08.csv
# 2    regional-us-weekly-2020-05-01--2020-05-08.csv
# 3    regional-us-weekly-2020-05-01--2020-05-08.csv
# 4    regional-us-weekly-2020-05-01--2020-05-08.csv
# ..                                             ...
# 195  regional-us-weekly-2020-05-22--2020-05-29.csv
# 196  regional-us-weekly-2020-05-22--2020-05-29.csv
# 197  regional-us-weekly-2020-05-22--2020-05-29.csv
# 198  regional-us-weekly-2020-05-22--2020-05-29.csv
# 199  regional-us-weekly-2020-05-22--2020-05-29.csv
#
# [800 rows x 6 columns]

# %%
may_combined_df_top200["Month"] = ""
may_combined_df_top200['Date'] = may_combined_df_top200['Filename'].str.slice(19,29)
may_combined_df_top200['Date'] = pd.to_datetime(may_combined_df_top200['Date'])
may_combined_df_top200["Week Number"] = may_combined_df_top200['Date'].dt.week
may_combined_df_top200['Type'] = ''


for index, row in may_combined_df_top200.iterrows():
    may_combined_df_top200.loc[index, "Month"] = "May"
    may_combined_df_top200.loc[index, "Type"] = "Top 200"

#viral slicing is 16, 26
#top 200 slicing is 19,29
may_combined_df_top200.to_csv("may_combined_df_top200.csv")



may_combined_df_top200
# Out:
#      Position                                Track Name               Artist  \
# 0           1                                THE SCOTTS           THE SCOTTS
# 1           2                              Toosie Slide                Drake
# 2           3            Pain 1993 (with Playboi Carti)                Drake
# 3           4              ROCKSTAR (feat. Roddy Ricch)               DaBaby
# 4           5              Savage Remix (feat. Beyoncé)  Megan Thee Stallion
# ..        ...                                       ...                  ...
# 195       196                                   Legends           Juice WRLD
# 196       197  Meant to Be (feat. Florida Georgia Line)           Bebe Rexha
# 197       198                                 Hurricane           Luke Combs
# 198       199                            No Role Modelz              J. Cole
# 199       200                                 Lights Up         Harry Styles
#
#       Streams                                                URL  \
# 0    12864147  https://open.spotify.com/track/39Yp9wwQiSRIDOv...
# 1    11648985  https://open.spotify.com/track/466cKvZn1j45Ipx...
# 2    10082722  https://open.spotify.com/track/6Kj17Afjo1OKJYp...
# 3    10028561  https://open.spotify.com/track/7ytR5pFWmSjzHJI...
# 4     8965215  https://open.spotify.com/track/5v4GgrXPMghOnBB...
# ..        ...                                                ...
# 195   1496245  https://open.spotify.com/track/1Knctxx9vGZxpZf...
# 196   1495527  https://open.spotify.com/track/4e4fqjx0Izh4svv...
# 197   1495471  https://open.spotify.com/track/6xHI9KjUjYT0FPt...
# 198   1495066  https://open.spotify.com/track/62vpWI1CHwFy7tM...
# 199   1494534  https://open.spotify.com/track/4jAIqgrPjKLTY9G...
#
#                                           Filename Month       Date  \
# 0    regional-us-weekly-2020-05-01--2020-05-08.csv   May 2020-05-01
# 1    regional-us-weekly-2020-05-01--2020-05-08.csv   May 2020-05-01
# 2    regional-us-weekly-2020-05-01--2020-05-08.csv   May 2020-05-01
# 3    regional-us-weekly-2020-05-01--2020-05-08.csv   May 2020-05-01
# 4    regional-us-weekly-2020-05-01--2020-05-08.csv   May 2020-05-01
# ..                                             ...   ...        ...
# 195  regional-us-weekly-2020-05-22--2020-05-29.csv   May 2020-05-22
# 196  regional-us-weekly-2020-05-22--2020-05-29.csv   May 2020-05-22
# 197  regional-us-weekly-2020-05-22--2020-05-29.csv   May 2020-05-22
# 198  regional-us-weekly-2020-05-22--2020-05-29.csv   May 2020-05-22
# 199  regional-us-weekly-2020-05-22--2020-05-29.csv   May 2020-05-22
#
#      Week Number     Type
# 0             18  Top 200
# 1             18  Top 200
# 2             18  Top 200
# 3             18  Top 200
# 4             18  Top 200
# ..           ...      ...
# 195           21  Top 200
# 196           21  Top 200
# 197           21  Top 200
# 198           21  Top 200
# 199           21  Top 200
#
# [800 rows x 10 columns]

# %%
# Merge top 200
files = glob.glob('Resources/Viral50/May/*.csv')
# print(files)

may_combined_df_viral50 = pd.concat([pd.read_csv(fp).assign(Filename=os.path.basename(fp)) for fp in files])

may_combined_df_viral50
may_combined_df_viral50 = may_combined_df_viral50.sort_values(['Filename', "Position"], ascending=True)

# %%
may_combined_df_viral50
# Out:
#     Position                            Track Name          Artist  \
# 0          1                                50//50         Vantage
# 1          2  ily (i love you baby) (feat. Emilee)       Surf Mesa
# 2          3                         Con Tus Besos  Eslabon Armado
# 3          4                                   LMK        Lil Xxel
# 4          5                                  Yoga           645AR
# ..       ...                                   ...             ...
# 45        46                          Break Things    Kylie Morgan
# 46        47                              Skechers      DripReport
# 47        48                          Disingenuous          Flight
# 48        49                           Sunday Best        Surfaces
# 49        50                           Breaking Me           Topic
#
#                                                   URL  \
# 0   https://open.spotify.com/track/36lNDeaRf8F8aYa...
# 1   https://open.spotify.com/track/62aP9fBQKYKxi7P...
# 2   https://open.spotify.com/track/6WYB1odDfMPVMyp...
# 3   https://open.spotify.com/track/0efL46uAuNEfukX...
# 4   https://open.spotify.com/track/2DiybJZJGXyV1UY...
# ..                                                ...
# 45  https://open.spotify.com/track/45hbxz8xCxQfa9v...
# 46  https://open.spotify.com/track/2alc8VZAzDgdAsL...
# 47  https://open.spotify.com/track/77N3t8CNrUQV2f2...
# 48  https://open.spotify.com/track/1Cv1YLb4q0RzL6p...
# 49  https://open.spotify.com/track/3H7ihDc1dqLriiW...
#
#                                       Filename
# 0   viral-us-weekly-2020-05-07--2020-05-07.csv
# 1   viral-us-weekly-2020-05-07--2020-05-07.csv
# 2   viral-us-weekly-2020-05-07--2020-05-07.csv
# 3   viral-us-weekly-2020-05-07--2020-05-07.csv
# 4   viral-us-weekly-2020-05-07--2020-05-07.csv
# ..                                         ...
# 45  viral-us-weekly-2020-05-28--2020-05-28.csv
# 46  viral-us-weekly-2020-05-28--2020-05-28.csv
# 47  viral-us-weekly-2020-05-28--2020-05-28.csv
# 48  viral-us-weekly-2020-05-28--2020-05-28.csv
# 49  viral-us-weekly-2020-05-28--2020-05-28.csv
#
# [200 rows x 5 columns]

# %%
may_combined_df_viral50["Month"] = ""
may_combined_df_viral50['Date'] = may_combined_df_viral50['Filename'].str.slice(16,26)
may_combined_df_viral50['Date'] = pd.to_datetime(may_combined_df_viral50['Date'])
may_combined_df_viral50["Week Number"] = may_combined_df_viral50['Date'].dt.week
may_combined_df_viral50['Type'] = ''


for index, row in may_combined_df_viral50.iterrows():
    may_combined_df_viral50.loc[index, "Month"] = "May"
    may_combined_df_viral50.loc[index, "Type"] = "Viral 50"

#viral slicing is 16, 26
#top 200 slicing is 19,29
may_combined_df_viral50.to_csv("may_combined_df_viral50.csv")



may_combined_df_viral50
# Out:
#     Position                            Track Name          Artist  \
# 0          1                                50//50         Vantage
# 1          2  ily (i love you baby) (feat. Emilee)       Surf Mesa
# 2          3                         Con Tus Besos  Eslabon Armado
# 3          4                                   LMK        Lil Xxel
# 4          5                                  Yoga           645AR
# ..       ...                                   ...             ...
# 45        46                          Break Things    Kylie Morgan
# 46        47                              Skechers      DripReport
# 47        48                          Disingenuous          Flight
# 48        49                           Sunday Best        Surfaces
# 49        50                           Breaking Me           Topic
#
#                                                   URL  \
# 0   https://open.spotify.com/track/36lNDeaRf8F8aYa...
# 1   https://open.spotify.com/track/62aP9fBQKYKxi7P...
# 2   https://open.spotify.com/track/6WYB1odDfMPVMyp...
# 3   https://open.spotify.com/track/0efL46uAuNEfukX...
# 4   https://open.spotify.com/track/2DiybJZJGXyV1UY...
# ..                                                ...
# 45  https://open.spotify.com/track/45hbxz8xCxQfa9v...
# 46  https://open.spotify.com/track/2alc8VZAzDgdAsL...
# 47  https://open.spotify.com/track/77N3t8CNrUQV2f2...
# 48  https://open.spotify.com/track/1Cv1YLb4q0RzL6p...
# 49  https://open.spotify.com/track/3H7ihDc1dqLriiW...
#
#                                       Filename Month       Date  Week Number  \
# 0   viral-us-weekly-2020-05-07--2020-05-07.csv   May 2020-05-07           19
# 1   viral-us-weekly-2020-05-07--2020-05-07.csv   May 2020-05-07           19
# 2   viral-us-weekly-2020-05-07--2020-05-07.csv   May 2020-05-07           19
# 3   viral-us-weekly-2020-05-07--2020-05-07.csv   May 2020-05-07           19
# 4   viral-us-weekly-2020-05-07--2020-05-07.csv   May 2020-05-07           19
# ..                                         ...   ...        ...          ...
# 45  viral-us-weekly-2020-05-28--2020-05-28.csv   May 2020-05-28           22
# 46  viral-us-weekly-2020-05-28--2020-05-28.csv   May 2020-05-28           22
# 47  viral-us-weekly-2020-05-28--2020-05-28.csv   May 2020-05-28           22
# 48  viral-us-weekly-2020-05-28--2020-05-28.csv   May 2020-05-28           22
# 49  viral-us-weekly-2020-05-28--2020-05-28.csv   May 2020-05-28           22
#
#         Type
# 0   Viral 50
# 1   Viral 50
# 2   Viral 50
# 3   Viral 50
# 4   Viral 50
# ..       ...
# 45  Viral 50
# 46  Viral 50
# 47  Viral 50
# 48  Viral 50
# 49  Viral 50
#
# [200 rows x 9 columns]

# %%
files = glob.glob('Resources/Top200/July/*.csv')
# print(files)

july_combined_df_top200 = pd.concat([pd.read_csv(fp, skiprows=[0], skip_blank_lines=True).assign(Filename=os.path.basename(fp)) for fp in files])

july_combined_df_top200
july_combined_df_top200 = july_combined_df_top200.sort_values(['Filename', "Position"], ascending=True)

# %%
july_combined_df_top200["Month"] = ""
july_combined_df_top200['Date'] = july_combined_df_top200['Filename'].str.slice(19,29)
july_combined_df_top200['Date'] = pd.to_datetime(july_combined_df_top200['Date'])
july_combined_df_top200["Week Number"] = july_combined_df_top200['Date'].dt.week
july_combined_df_top200['Type'] = ''


for index, row in july_combined_df_top200.iterrows():
    july_combined_df_top200.loc[index, "Month"] = "July"
    july_combined_df_top200.loc[index, "Type"] = "Top 200"

#viral slicing is 16, 26
#top 200 slicing is 19,29
july_combined_df_top200.to_csv("july_combined_df_top200.csv")



july_combined_df_top200
# Out:
#      Position                                         Track Name  \
# 0           1                       ROCKSTAR (feat. Roddy Ricch)
# 1           2            For The Night (feat. Lil Baby & DaBaby)
# 2           3  WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil W...
# 3           4                                   Watermelon Sugar
# 4           5                                    Blueberry Faygo
# ..        ...                                                ...
# 195       196                                           Said Sum
# 196       197                                     Kings & Queens
# 197       198                                  Murder On My Mind
# 198       199                            NOT FAIR (feat. Corbin)
# 199       200                                     Wait a Minute!
#
#             Artist   Streams  \
# 0           DaBaby  10375792
# 1        Pop Smoke   7298716
# 2      Jack Harlow   7189682
# 3     Harry Styles   6689854
# 4        Lil Mosey   6492849
# ..             ...       ...
# 195   Moneybagg Yo   1553201
# 196        Ava Max   1550634
# 197      YNW Melly   1548730
# 198  The Kid LAROI   1547622
# 199         WILLOW   1542463
#
#                                                    URL  \
# 0    https://open.spotify.com/track/7ytR5pFWmSjzHJI...
# 1    https://open.spotify.com/track/0PvFJmanyNQMseI...
# 2    https://open.spotify.com/track/2MbdDtCv5LUVjYy...
# 3    https://open.spotify.com/track/6UelLqGlWMcVH1E...
# 4    https://open.spotify.com/track/22LAwLoDA5b4AaG...
# ..                                                 ...
# 195  https://open.spotify.com/track/45npF3MKvCa1sO7...
# 196  https://open.spotify.com/track/76nqCfJOcFFWBJN...
# 197  https://open.spotify.com/track/7eBqSVxrzQZtK2m...
# 198  https://open.spotify.com/track/2HrMDMckfCyM4Oc...
# 199  https://open.spotify.com/track/0y60itmpH0aPKsF...
#
#                                           Filename Month       Date  \
# 0    regional-us-weekly-2020-07-03--2020-07-10.csv  July 2020-07-03
# 1    regional-us-weekly-2020-07-03--2020-07-10.csv  July 2020-07-03
# 2    regional-us-weekly-2020-07-03--2020-07-10.csv  July 2020-07-03
# 3    regional-us-weekly-2020-07-03--2020-07-10.csv  July 2020-07-03
# 4    regional-us-weekly-2020-07-03--2020-07-10.csv  July 2020-07-03
# ..                                             ...   ...        ...
# 195  regional-us-weekly-2020-07-24--2020-07-31.csv  July 2020-07-24
# 196  regional-us-weekly-2020-07-24--2020-07-31.csv  July 2020-07-24
# 197  regional-us-weekly-2020-07-24--2020-07-31.csv  July 2020-07-24
# 198  regional-us-weekly-2020-07-24--2020-07-31.csv  July 2020-07-24
# 199  regional-us-weekly-2020-07-24--2020-07-31.csv  July 2020-07-24
#
#      Week Number     Type
# 0             27  Top 200
# 1             27  Top 200
# 2             27  Top 200
# 3             27  Top 200
# 4             27  Top 200
# ..           ...      ...
# 195           30  Top 200
# 196           30  Top 200
# 197           30  Top 200
# 198           30  Top 200
# 199           30  Top 200
#
# [800 rows x 10 columns]

# %%
# Merge top 200
files = glob.glob('Resources/Viral50/July/*.csv')
# print(files)

july_combined_df_viral50 = pd.concat([pd.read_csv(fp).assign(Filename=os.path.basename(fp)) for fp in files])

july_combined_df_viral50
july_combined_df_viral50 = july_combined_df_viral50.sort_values(['Filename', "Position"], ascending=True)

# %%
july_combined_df_viral50["Month"] = ""
july_combined_df_viral50['Date'] = july_combined_df_viral50['Filename'].str.slice(16,26)
july_combined_df_viral50['Date'] = pd.to_datetime(july_combined_df_viral50['Date'])
july_combined_df_viral50["Week Number"] = july_combined_df_viral50['Date'].dt.week
july_combined_df_viral50['Type'] = ''


for index, row in july_combined_df_viral50.iterrows():
    july_combined_df_viral50.loc[index, "Month"] = "July"
    july_combined_df_viral50.loc[index, "Type"] = "Viral 50"

#viral slicing is 16, 26
#top 200 slicing is 19,29
july_combined_df_viral50.to_csv("july_combined_df_viral50.csv")



july_combined_df_viral50
# Out:
#     Position                                         Track Name  \
# 0          1                                          I See Red
# 1          2                   Then Leave (feat. Queendom Come)
# 2          3                     Stunnin' (feat. Harm Franklin)
# 3          4                                          Hood Baby
# 4          5                                        Hard For Me
# ..       ...                                                ...
# 45        46                      Past Life (with Selena Gomez)
# 46        47                                Судно (Борис Рижий)
# 47        48                                              Renee
# 48        49  PORFA Remix ( Feat. Maluma, Nicky Jam, Sech) -...
# 49        50                                               Baby
#
#                        Artist  \
# 0   Everybody Loves an Outlaw
# 1                    BeatKing
# 2               Curtis Waters
# 3                        KBFR
# 4             Michele Morrone
# ..                        ...
# 45              Trevor Daniel
# 46               Molchat Doma
# 47                      SALES
# 48                       Feid
# 49             Eslabon Armado
#
#                                                   URL  \
# 0   https://open.spotify.com/track/2Xau3uNsnIb9Fwz...
# 1   https://open.spotify.com/track/2Xoc4gqPbBa3QHK...
# 2   https://open.spotify.com/track/2D0dj3hVkRQJCp6...
# 3   https://open.spotify.com/track/5au5NgWCdev4WeL...
# 4   https://open.spotify.com/track/00PesUdTmC3Y5xt...
# ..                                                ...
# 45  https://open.spotify.com/track/4P6IttK2PRBjyr3...
# 46  https://open.spotify.com/track/6DONTnamNDOJdO6...
# 47  https://open.spotify.com/track/5MeUMSRreLHYLhw...
# 48  https://open.spotify.com/track/7lUdbnz7wsv3C9z...
# 49  https://open.spotify.com/track/3lbCkWmaQKphoT2...
#
#                                       Filename Month       Date  Week Number  \
# 0   viral-us-weekly-2020-07-02--2020-07-02.csv  July 2020-07-02           27
# 1   viral-us-weekly-2020-07-02--2020-07-02.csv  July 2020-07-02           27
# 2   viral-us-weekly-2020-07-02--2020-07-02.csv  July 2020-07-02           27
# 3   viral-us-weekly-2020-07-02--2020-07-02.csv  July 2020-07-02           27
# 4   viral-us-weekly-2020-07-02--2020-07-02.csv  July 2020-07-02           27
# ..                                         ...   ...        ...          ...
# 45  viral-us-weekly-2020-07-23--2020-07-23.csv  July 2020-07-23           30
# 46  viral-us-weekly-2020-07-23--2020-07-23.csv  July 2020-07-23           30
# 47  viral-us-weekly-2020-07-23--2020-07-23.csv  July 2020-07-23           30
# 48  viral-us-weekly-2020-07-23--2020-07-23.csv  July 2020-07-23           30
# 49  viral-us-weekly-2020-07-23--2020-07-23.csv  July 2020-07-23           30
#
#         Type
# 0   Viral 50
# 1   Viral 50
# 2   Viral 50
# 3   Viral 50
# 4   Viral 50
# ..       ...
# 45  Viral 50
# 46  Viral 50
# 47  Viral 50
# 48  Viral 50
# 49  Viral 50
#
# [200 rows x 9 columns]
